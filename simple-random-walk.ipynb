# %% [markdown]
# # Simple Random Walk

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 1
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
def simple_ramdom_walk(step, dim=1):
    r = np.random.choice(dim*2, step)
    one_hot = np.identity(dim*2, dtype=int)[r]
    one_hot = one_hot.T
    diff = one_hot[:dim] - one_hot[dim:]
    diff[:, 0] = 0
    walk = np.cumsum(diff, axis=1)
    if dim == 1:
        walk = walk[0]
    return walk

# %% [markdown]
# ### 1 dimension

# %%
step = 3000

fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(1, 1, 1)

walk = simple_ramdom_walk(step)

t = []
x = list()
for i, coord in enumerate(walk):
    t.extend([i, i+1])
    x.extend([coord]*2)

ax.plot(t, x)
plt.show()

# %%
step = 3000
num = 20

fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(1, 1, 1)

for _ in range(10):
    walk = simple_ramdom_walk(step)
    t = []
    x = list()
    for i, coord in enumerate(walk):
        t.extend([i, i+1])
        x.extend([coord]*2)
    ax.plot(t, x)
plt.show()

# %% [markdown]
# ### 2 dimension

# %%
step = 3000
dim = 2

fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(1, 1, 1)
plt.gca().set_aspect('equal', adjustable='box') # equalize the scales of x-axis and y-axis

x, y = simple_ramdom_walk(step, dim)
ax.plot(x, y)
plt.show()

# %%
step = 3000
dim = 2
num = 10

fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(1, 1, 1)
plt.gca().set_aspect('equal', adjustable='box') # equalize the scales of x-axis and y-axis

for _ in range(num):
    x, y = simple_ramdom_walk(step, dim)
    ax.plot(x, y)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

step = 3000
dim = 3

fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')
plt.gca().set_aspect('equal', adjustable='box')

x, y, z = simple_ramdom_walk(step, dim)
ax.plot(x, y, z)
plt.show()

# %%
step = 3000
dim = 3
num = 10

fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')
plt.gca().set_aspect('equal', adjustable='box')

for _ in range(num):
    x, y, z = simple_ramdom_walk(step, dim)
    ax.plot(x, y, z)
plt.show()

# %% [markdown]
# ## Recurrency of Simple random walk
# Fact: **2** dimensional Brownian motions have the recursiveness, but **3 or more** dimensional Brownian motions don't.

# %%
step = 10000
num = 10000

cross_num = 0
for _ in range(num):
    x = simple_ramdom_walk(step)[1:]
    cross_num += np.any(x == 0)
prob = cross_num / num
print(f'Trial number: {num}')
print(f'Cross number: {cross_num}')
print(f'Probability: {prob}')
# Out:
# Trial number: 10000
# Cross number: 9914
# Probability: 0.9914

# %%
step = 10000
dim = 2
num = 10000

cross_num = 0
for n in range(num):
    x = simple_ramdom_walk(step, dim)[:, 1:]
    cross_num += np.any(np.sum(np.abs(x), axis=0) == 0)
prob = cross_num / num
print(f'Trial number: {num}')
print(f'Cross number: {cross_num}')
print(f'Probability: {prob}')
# Out:
# Trial number: 10000
# Cross number: 7390
# Probability: 0.739

# %%
step = 10000
dim = 3
num = 10000

cross_num = 0
for n in range(num):
    x = simple_ramdom_walk(step, dim)[:, 1:]
    cross_num += np.any(np.sum(np.abs(x), axis=0) == 0)
prob = cross_num / num
print(f'Trial number: {num}')
print(f'Cross number: {cross_num}')
print(f'Probability: {prob}')
# Out:
# Trial number: 10000
# Cross number: 3310
# Probability: 0.331

# %%
step = 10000
dim = 4
num = 10000

cross_num = 0
for n in range(num):
    x = simple_ramdom_walk(step, dim)[:, 1:]
    cross_num += np.any(np.sum(np.abs(x), axis=0) == 0)
prob = cross_num / num
print(f'Trial number: {num}')
print(f'Cross number: {cross_num}')
print(f'Probability: {prob}')
# Out:
# Trial number: 10000
# Cross number: 1863
# Probability: 0.1863

# %%
step = 10000
dim = 10
num = 10000

cross_num = 0
for n in range(num):
    x = simple_ramdom_walk(step, dim)[:, 1:]
    cross_num += np.any(np.sum(np.abs(x), axis=0) == 0)
prob = cross_num / num
print(f'Trial number: {num}')
print(f'Cross number: {cross_num}')
print(f'Probability: {prob}')
# Out:
# Trial number: 10000
# Cross number: 600
# Probability: 0.06
